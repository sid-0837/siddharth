# %% [markdown]
# <a href="https://colab.research.google.com/github/sid-0837/siddharth/blob/main/martixvisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
data=np.random.random((13,16))
plt.imshow(data,cmap="magma")
plt.title("2-D Heat Map")
plt.colorbar()
plt.show()

# %%
import seaborn as sns
data=np.random.randint(low=14,high=100,size=(10,10))
nm=sns.heatmap(data=data,annot=True)
plt.show()
