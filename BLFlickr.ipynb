# %%
import pandas as pd

# %%
import numpy as np

# %%
from functools import reduce

# %%
df=pd.read_csv("/content/drive/MyDrive/Datasets/BL-Flickr-Images-Book (1).csv")

# %%
df.shape
# Out:
# (8287, 15)

# %%
for col in df:
  print(col);
# Out:
# Identifier
# Edition Statement
# Place of Publication
# Date of Publication
# Publisher
# Title
# Author
# Contributors
# Corporate Author
# Corporate Contributors
# Former owner
# Engraver
# Issuance type
# Flickr URL
# Shelfmarks

# %%
to_drop=["Edition Statement",'Corporate Author','Corporate Author','Corporate Contributors','Former Owner','Engraver','Contributor','Shelf Marks']

# %%
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
print(col)
# Out:
# Shelfmarks

# %%
df.set_index('Identifier',inplace=True)
df.head()
# Out:
#                        Edition Statement      Place of Publication  \
# Identifier
# 206                                  NaN                    London
# 216                                  NaN  London; Virtue & Yorston
# 218                                  NaN                    London
# 472                                  NaN                    London
# 480         A new edition, revised, etc.                    London
#
#            Date of Publication              Publisher  \
# Identifier
# 206                1879 [1878]       S. Tinsley & Co.
# 216                       1868           Virtue & Co.
# 218                       1869  Bradbury, Evans & Co.
# 472                       1851          James Darling
# 480                       1857   Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# ...

# %%
df['Date of Publication'].head(25)
# Out:
# Identifier
# 206            1879 [1878]
# 216                   1868
# 218                   1869
# 472                   1851
# 480                   1857
# 481                   1875
# 519                   1872
# 667                    NaN
# 874                   1676
# 1143                  1679
# 1280                  1802
# 1808                  1859
# 1905                  1888
# 1929           1839, 38-54
# 2836                  1897
# 2854                  1865
# 2956               1860-63
# 2957                  1873
# 3017                  1866
# 3131                  1899
# 4598                  1814
# 4884                  1820
# 4976                  1800
# 5382    1847, 48 [1846-48]
# 5385               [1897?]
# Name: Date of Publication, dtype: object

# %%
unwanted_characters=['[', ',', ',', '-']
def clean_dates(item):
  dop=str(item.loc['Date of Publication'])
  if dop =='NaN' or dop[0]== '[':
    return np.NaN
  for character in unwanted_characters :
    if character in dop:
       character_index = dop.find(character)
       dop = dop[:character_index]
  return dop
df['Date of Publication']=df.apply(clean_dates,axis=1)

# %%
def clean_title(title):


 if title == 'nan':

    return 'NaN'

 if title[0] == '[':

     title = title [1: title.find(']')]

 if 'by' in title:

   title = title[:title.find('by')]

 elif 'By' in title:

  title = title[:title.find('By')]

 if '[' in title:

     title = title[:title.find('[')]

 title = title[:-2]

df['Title'] = df['Title'].apply(clean_title)

df.head()
# Out:
#                        Edition Statement      Place of Publication  \
# Identifier
# 206                                  NaN                    London
# 216                                  NaN  London; Virtue & Yorston
# 218                                  NaN                    London
# 472                                  NaN                    London
# 480         A new edition, revised, etc.                    London
#
#            Date of Publication              Publisher Title     Author  \
# Identifier
# 206                      1879        S. Tinsley & Co.  None      A. A.
# 216                       1868           Virtue & Co.  None  A., A. A.
# 218                       1869  Bradbury, Evans & Co.  None  A., A. A.
# 472                       1851          James Darling  None  A., E. S.
# 480                       1857   Wertheim & Macintosh  None  A., E. S.
#
#                                             Contributors  Corporate Author  \
# Identifier
# ...
